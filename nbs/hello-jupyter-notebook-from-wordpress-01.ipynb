# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 2, 3, 4], [12, 20, 22, 32], color='red', linewidth=3)
ax.scatter([1.5, 2.1, 3.5, 4.2], [18, 19, 30.5, 29], color='blue', marker='o', linewidth=3)
ax.set_xlim(0.5, 4.5)

plt.show()
