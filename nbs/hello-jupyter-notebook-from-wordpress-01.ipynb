# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 2, 3, 4], [10, 20, 22, 30], color='red', linewidth=3)
ax.scatter([1.5, 2.9, 4.2, 3.5], [18, 35, 24, 29], color='green', marker='^')
ax.set_xlim(0.5, 4.5)

plt.show()
